# %%
library (tidyverse)

# %%
data()

# %%
?starwars

# %%
# View(starwars) # not yet supported in the Jupyter R kernel

# %%
starwars %>%
    filter(hair_color == "black" | hair_color =="brown") %>%
    drop_na(gender) %>%
    ggplot(aes(hair_color, fill = gender)) +
    geom_bar(position = "dodge", alpha =0.5) +
    theme_bw()
# Out:
# plot without title

# %%
starwars %>%
    filter(hair_color == "black" | hair_color =="brown") %>%
    drop_na(gender) %>%
    ggplot(aes(hair_color, fill = gender)) +
    geom_bar(position = "dodge", alpha =0.5) +
    theme_bw()+
    theme(panel.grid.major = element_blank(),
          panel.grid.minor = element_blank())+
    labs(title = "Gender and Hair Colour",
         x = "Hair Colour",
         y = "Number")
# Out:
# plot without title

# %%
?msleep

# %%
msleep %>%
    ggplot(aes(x = awake)) + 
    geom_histogram(binwidth = 2, fill = "#1250A5") +
    theme_grey () +
    labs(x = "sleep_total",
         y = NULL,
         title = "Hist of tt sleep")
# Out:
# plot without title

# %%
msleep %>%
    drop_na(vore) %>%
    ggplot(aes(x=vore))+
    geom_bar (fill = "#1250A5")+
    coord_flip()+
    theme_bw()+
    labs(x = "Yore",
        y = NULL,
        title = "Number of observations per order")
# Out:
# plot without title

# %%
msleep %>%
    drop_na(vore) %>%
    ggplot(aes(x=vore, y=bodywt))+
    geom_boxplot (fill = "#1250A5")+
    coord_flip()+
    theme_bw()+
    labs(x = "Yore",
        y = NULL,
        title = "Number of observations per order")
# Out:
# plot without title
